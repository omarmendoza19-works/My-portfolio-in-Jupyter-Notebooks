# %%
import os 
import pandas as pd 
import warnings 
warnings.filterwarnings('ignore')

os.chdir('D:\PYTHON')
data = pd.read_csv('creditcard.csv')
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
import matplotlib.pyplot as plt 
import seaborn as sns 
plt.figure(figsize = (20,7))
sns.heatmap(data.isnull(), yticklabels = False, cbar = False, cmap = 'viridis')
# Out:
# <Axes: >

# %%
data.corr()
# Out:
#             Time            V1            V2            V3            V4  \
# Time    1.000000  1.173963e-01 -1.059333e-02 -4.196182e-01 -1.052602e-01
# V1      0.117396  1.000000e+00  4.135835e-16 -1.227819e-15 -9.215150e-16
# V2     -0.010593  4.135835e-16  1.000000e+00  3.243764e-16 -1.121065e-15
# V3     -0.419618 -1.227819e-15  3.243764e-16  1.000000e+00  4.711293e-16
# V4     -0.105260 -9.215150e-16 -1.121065e-15  4.711293e-16  1.000000e+00
# V5      0.173072  1.812612e-17  5.157519e-16 -6.539009e-17 -1.719944e-15
# V6     -0.063016 -6.506567e-16  2.787346e-16  1.627627e-15 -7.491959e-16
# V7      0.084714 -1.005191e-15  2.055934e-16  4.895305e-16 -4.104503e-16
# V8     -0.036949 -2.433822e-16 -5.377041e-17 -1.268779e-15  5.697192e-16
# V9     -0.008660 -1.513678e-16  1.978488e-17  5.568367e-16  6.923247e-16
# V10     0.030617  7.388135e-17 -3.991394e-16  1.156587e-15  2.232685e-16
# V11    -0.247689  2.125498e-16  1.975426e-16  1.576830e-15  3.459380e-16
# ...

# %%
data.dropna()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
import matplotlib.pyplot as plt 
fig, ax = plt.subplots()
ax.scatter(data['Class'], data['Amount'])
ax.set_ylabel('Cantidad')
ax.set_xlabel('Fraude')
plt.show()

# %%
import seaborn as sns
sns.heatmap(data.corr())
# Out:
# <Axes: >

# %%
X = data.iloc[:, 0:30].values
Y = data.Class

# %% [markdown]
# # Decision Tree

# %%
 from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 1)

# %%
clf = DecisionTreeClassifier()
clf = clf.fit(X_train, Y_train)

# %%
clf.score(X_train, Y_train)
# Out:
# 1.0

# %%
clf.score(X_test, Y_test)
# Out:
# 0.9992626663389628

# %%
from sklearn.metrics import classification_report 
Y_pred = clf.predict(X_test)
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56875
#            1       0.78      0.72      0.75        87
#
#     accuracy                           1.00     56962
#    macro avg       0.89      0.86      0.87     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
from sklearn.metrics import precision_recall_curve, auc
precision, recall, _ = precision_recall_curve(Y_test, Y_pred)
auprc = auc(recall, precision)
print('AUPRC: ', auprc)
# Out:
# AUPRC:  0.7511685211664266

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators = 100, random_state = 1)
rf.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(random_state=1)

# %%
rf.score(X_train, Y_train)
# Out:
# 1.0

# %%
rf.score(X_test, Y_test)
# Out:
# 0.9995611109160493

# %%
Y_pred = rf.predict(X_test)
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56875
#            1       0.93      0.77      0.84        87
#
#     accuracy                           1.00     56962
#    macro avg       0.97      0.89      0.92     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
precision, recall, _ = precision_recall_curve(Y_test, Y_pred)
auprc = auc(recall, precision)
print('AUPRC: ', auprc)
# Out:
# AUPRC:  0.8505108046757258

# %% [markdown]
# # Gradient Boosting Trees

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbt = GradientBoostingClassifier(n_estimators = 100, random_state = 1)
gbt.fit(X_train, Y_train)
# Out:
# GradientBoostingClassifier(random_state=1)

# %%
gbt.score(X_train, Y_train)
# Out:
# 0.9995435493427549

# %%
gbt.score(X_test, Y_test)
# Out:
# 0.9993153330290369

# %%
Y_pred = gbt.predict(X_test)
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56875
#            1       0.86      0.66      0.75        87
#
#     accuracy                           1.00     56962
#    macro avg       0.93      0.83      0.87     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
precision, recall, _ = precision_recall_curve(Y_test, Y_pred)
auprc = auc(recall, precision)
print('AUPRC: ', auprc)
# Out:
# AUPRC:  0.759667722165104

# %% [markdown]
# # Redes Neuronales

# %%
import tensorflow as tf 
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, Dropout
from sklearn.preprocessing import StandardScaler 

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = Sequential()
model.add(Dense(64, activation = 'relu', input_shape = (X_train.shape[1],)))
model.add(Dropout(0.5))
model.add(Dense(64, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation = 'sigmoid'))
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
training = model.fit(X_train, Y_train, epochs = 50, batch_size = 32, validation_split = 0.2)
# Out:
# Epoch 1/50
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.9869 - loss: 0.0403 - val_accuracy: 0.9993 - val_loss: 0.0042
# Epoch 2/50
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - accuracy: 0.9993 - loss: 0.0040 - val_accuracy: 0.9993 - val_loss: 0.0042
# Epoch 3/50
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - accuracy: 0.9993 - loss: 0.0049 - val_accuracy: 0.9993 - val_loss: 0.0034
# Epoch 4/50
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - accuracy: 0.9994 - loss: 0.0037 - val_accuracy: 0.9993 - val_loss: 0.0042
# Epoch 5/50
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - accuracy: 0.9994 - loss: 0.0037 - val_accuracy: 0.9992 - val_loss: 0.0041
# Epoch 6/50
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - accuracy: 0.9994 - loss: 0.0038 - val_accuracy: 0.9992 - val_loss: 0.0038
# Epoch 7/50
# 5697/5697 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - accuracy: 0.9993 - loss: 0.0042 - val_accuracy: 0.9991 - val_loss: 0.0043
# Epoch 8/50
# ...

# %%
test_loss, test_acc = model.evaluate(X_test, Y_test)
print('Precision en los grupos de prueba: ', test_acc)
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 1s 643us/step - accuracy: 0.9992 - loss: 0.0120
# Precision en los grupos de prueba:  0.9992977976799011

# %%
Y_pred = (model.predict(X_test) > 0.5).astype(int)
print(classification_report(Y_test, Y_pred))
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 1s 658us/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56875
#            1       0.83      0.68      0.75        87
#
#     accuracy                           1.00     56962
#    macro avg       0.92      0.84      0.87     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
precision, recall, _ = precision_recall_curve(Y_test, Y_pred)
auprc = auc(recall, precision)
print('AUPRC: ', auprc)
# Out:
# AUPRC:  0.7548191954036062

# %% [markdown]
# # Prueba para hacer predicciones

# %%
rf.predict([[4485,-3.220662743,2.958986997,0.997770212,0.702393951, -2.774302741,1.644341497,-2.501857062,
             1.683583791, 1.617189621, -0.836631174, -0.011615371,-1.391619862,2.132108052,1.389910816,
             -0.819227672,-0.735870238,1.97566964,-0.001796068,0.276442779, 0.074319408, -0.029428243,
             0.415389543,-0.088684128,0.373337893,0.38237869,-0.084540537,0.235961843,0.080339665,
             5
 ]])
# Out:
# array([0], dtype=int64)

# %%
rf.predict([[7278,-1.711324338,2.063586465,1.678737368,-0.840003793,-0.040424376,-0.527545844,0.214914735,
             0.143601498,1.833624034,-1.341677967,-0.10243179,-2.620706153,-2.131709427,0.697000158,
             -0.952213491,-0.187435153,2.024181041,-1.696747831,-1.576288168,-1.207901801,-2.326001284,
             -1.825379557,2.182520295,0.000311324,-0.680790601,1.015048917,-0.037801286,0.110599299,
             40
]])
# Out:
# array([0], dtype=int64)

# %%
rf.predict([[12393,-4.064004738,3.100934891,-1.188498004,3.26463274,-1.903562358,0.320350587,-0.954940039,
             -3.27753492,2.820828662,1.01511288,3.187186897,-7.004327284,0.872710605,-6.220605353,
             -0.90444463,-3.075091885,-5.044735692,-1.718082685,-0.662462068,-0.531897693,1.688665431,
             -0.078844698,0.193730927,0.479495954,-0.506603057,-0.409862744,-3.036271329,-0.630605199,
             179.66
]])
# Out:
# array([1], dtype=int64)
